# %% [markdown]
# # Task
# Load the 'test' and 'train' splits from the 'strategyqa_dataset', 'maqa_datasets', and 'gsm8k_datasets' into pandas DataFrames.

# %% [markdown]
# ## Explore Dataset Directories
#
# ### Subtask:
# Examine the file structure and types within the 'strategyqa_dataset', 'maqa_datasets', and 'gsm8k_datasets' directories to determine the best method for loading data into pandas DataFrames, specifically looking for 'test' and 'train' splits. This involves listing files and their extensions.

# %% [markdown]
# **Reasoning**:
# To begin exploring the dataset directories, I will first use the `ls -R` command to list the contents of the root directory and confirm the presence and structure of the requested dataset directories.

# %%
import os

# List the contents of the /content directory to see available files and directories
print("Contents of /content/:")
# !ls -R /content/

# Try to list the contents of the specified dataset directories directly.
# If they don't exist, the command will fail, and we'll address that in the next step.

# 1. List the contents of 'strategyqa_dataset' directory
print("\nContents of strategyqa_dataset:")
# !ls -R /content/strategyqa_dataset

# 2. List the contents of 'maqa_datasets' directory
print("\nContents of maqa_datasets:")
# !ls -R /content/maqa_datasets

# 3. List the contents of 'gsm8k_datasets' directory
print("\nContents of gsm8k_datasets:")
# !ls -R /content/gsm8k_datasets
# Out:
# Contents of /content/:
# /content/:
# drive  sample_data
#
# /content/drive:
# MyDrive
#
# /content/drive/MyDrive:
# 'aasta 1'
#  andmetehnika
# 'andmete visualiseerimine'
# 'atm andmeteaduse meetodid'
# 'Colab Notebooks'
#  DataEngineeringProject.gdoc
#  digihumanitaaria
# 'eesti keel pythonis'
# 'koodihalduse alused'
# 'Machine Learning Homework 05.gdoc'
#  masinope
# 'notebook converter'
# 'Slideless presentation.gdoc'
#  transformers
# 'Transformers course homework.gdoc'
# 'Transformers HW 03.gdoc'
# 'Transformers Project.gdoc'
# 'Üksuse UT ML project proposals 2025 koopia.gsheet'
#
# '/content/drive/MyDrive/aasta 1':
#
# /content/drive/MyDrive/andmetehnika:
# EntityDiagram.drawio
#
# '/content/drive/MyDrive/andmete visualiseerimine':
# kodutöö2  praks10
#
# '/content/drive/MyDrive/andmete visualiseerimine/kodutöö2':
# births_year.RData  Kodutoo2.Rmd  linnad.RData  ylevaatused.RData
#
# '/content/drive/MyDrive/andmete visualiseerimine/praks10':
# Blah.pdf  images  PF16_2024.RData  Praktikum10-2025S.Rmd  test.RData
#
# '/content/drive/MyDrive/andmete visualiseerimine/praks10/images':
# 'Screenshot 2021-03-07 at 22.17.02.png'
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid':
# 'kodutöö 01'  'kodutöö 04'	'praks 02'  'praks 05'	'praks 08'
# 'kodutöö 02'  'kontrolltöö 01'	'praks 03'  'praks 06'	'praks 09'
# 'kodutöö 03'  'praks 01'	'praks 04'  'praks 07'
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid/kodutöö 01':
# ATM2025_kodutoo_1.ipynb  synnikaalu_andmed.csv
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid/kodutöö 02':
# ATM2025_kodutoo_2.ipynb  yl1.csv  yl2.csv
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid/kodutöö 03':
# ATM2025_kodutoo_3.ipynb  kliima_tartu.csv
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid/kodutöö 04':
# ATM2025_kodutoo_4.ipynb
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid/kontrolltöö 01':
# IMG-20251026-WA0001.jpg  midtermexam_memo2.pdf	midtermexam_memo3.pdf
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid/praks
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid/praks 08':
#
# '/content/drive/MyDrive/atm andmeteaduse meetodid/praks 09':
# ATM2025_praktikum_9_u╠łlesanded.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks':
#  machine_learning_project.ipynb
# 'Märkmiku 3_Deeplearning_HW.ipynb koopia'
# 'Märkmiku machine_learning_project.ipynb koopia'
# 'Märkmiku Notebook_converter!.ipynb koopia'
# 'Märkmiku Praktikum_2.ipynb koopia'
# 'Märkmiku Praktikum_3.ipynb koopia'
# 'Märkmiku Praktikum_3.ipynb koopia (1)'
# 'Märkmiku Transformers2025_lab1_toy_model.ipynb koopia'
# 'Märkmiku Transformers2025_lab1_toy_model.ipynb koopia (1)'
#  Untitled0.ipynb
#
# /content/drive/MyDrive/digihumanitaaria:
# 'praks10 video'   praks5
#
# '/content/drive/MyDrive/digihumanitaaria/praks10 video':
# '2025-11-10 12-16-31.mp4'
#
# /content/drive/MyDrive/digihumanitaaria/praks5:
# data_science_and_dighum_slides.pdf	   introduction_to_nlp_pipeline.ipynb
# dighum_workshop_pandas_participants.ipynb
#
# '/content/drive/MyDrive/eesti keel pythonis':
# praks0	praks10  praks3  praks5  praks7  praks9		   praktikum2.zip
# praks1	praks2	 praks4  praks6  praks8  Praktikum_1.html
#
# '/content/drive/MyDrive/eesti keel pythonis/praks0':
# madasoo.txt   postimees.txt	 Praktikum_1.html   sonaloend.txt  tulemus2.txt
# nihilist.txt  Praktikum_1_files  Praktikum_1.ipynb  telegram.txt   tulemus.txt
#
# '/content/drive/MyDrive/eesti keel pythonis/praks0/Praktikum_1_files':
# 'bundle.js.Allalaaditud fail'
#  custom.css
#  index.css
#  logo-64x64.png
# 'remoteEntry.0dca0b46350f0c25c608.js.Allalaaditud fail'
# 'remoteEntry.235a4eb5f08bc399672c.js.Allalaaditud fail'
# 'remoteEntry.3318e43690692165b5ed.js.Allalaaditud fail'
# 'remoteEntry.36690a2bfa9ee0dd7bc8.js.Allalaaditud fail'
# 'remoteEntry.83218267865631694ab2.js.Allalaaditud fail'
# 'remoteEntry.c8393541423362724be3.js.Allalaaditud fail'
# 'remoteEntry.ca1efc27dc965162ca86.js.Allalaaditud fail'
# 'remoteEntry.cfbccb113f4c7c1d65fe.js.Allalaaditud fail'
# 'remoteEntry.ec403c961f3e6d85e7bc.js.Allalaaditud fail'
#
# '/content/drive/MyDrive/eesti keel pythonis/praks1':
# dummy_folder  parasiitlusest.txt  praktikum2.zip      wordcloud7.png
# hargla_texts  Praktikum_2.ipynb   presidendipilv.htm
# orlau_texts   Praktikum_2._ipynb  teatriarvustused2
#
# '/content/drive/MyDrive/eesti keel pythonis/praks1/dummy_folder':
# file1.txt  file2.txt
#
# '/content/drive/MyDrive/eesti keel pythonis/praks1/hargla_texts':
# ilu_hargla_jutt10.txt  ilu_hargla_jutt19.txt  ilu_hargla_jutt3.txt
# ilu_hargla_jutt11.txt  ilu_hargla_jutt1.txt   ilu_hargla_jutt4.txt
# ilu_hargla_jutt12.txt  ilu_hargla_jutt20.txt  ilu_hargla_jutt5.txt
# ilu_hargla_jutt13.txt  ilu_hargla_jutt21.txt  ilu_hargla_jutt6.txt
# ilu_hargla_jutt14.txt  ilu_hargla_jutt22.txt  ilu_hargla_jutt7.txt
# ilu_hargla_jutt15.txt  ilu_hargla_jutt23.txt  ilu_hargla_jutt8.txt
# ilu_hargla_jutt16.txt  ilu_hargla_jutt24.txt  ilu_hargla_jutt9.txt
# ilu_hargla_jutt17.txt  ilu_hargla_jutt25.txt
# ilu_hargla_jutt18.txt  ilu_hargla_jutt2.txt
#
# '/content/drive/MyDrive/eesti keel pythonis/pra
txt
#
# '/content/drive/MyDrive/eesti keel pythonis/praks4/__MACOSX':
#
# '/content/drive/MyDrive/eesti keel pythonis/praks5':
#  ajaleheartiklid        juku_1.txt	    vallakohtu_protokollid
#  anonymized_protocols   juku_2.txt
# 'Faili juku.txt'        Praktikum_5.ipynb
#
# '/content/drive/MyDrive/eesti keel pythonis/praks5/ajaleheartiklid':
# aja_aripaev_2008-02-11.txt   aja_maaleht_2009-11-04.txt
# aja_EPL_1999_01_29__20.txt   aja_maaleht_2017-02-23.txt
# aja_kroonika_2016-10-12.txt
#
# '/content/drive/MyDrive/eesti keel pythonis/praks5/anonymized_protocols':
# al0158_anonymiseeritud.txt  rn4835_anonymiseeritud.txt
# hj3742_anonymiseeritud.txt  va0057_anonymiseeritud.txt
# la0018_anonymiseeritud.txt
#
# '/content/drive/MyDrive/eesti keel pythonis/praks5/vallakohtu_protokollid':
# al0158.txt  hj3742.txt	la0018.txt  rn4835.txt	va0057.txt
#
# '/content/drive/MyDrive/eesti keel pythonis/praks6':
# aja_json	   yl1_naidistulem.jsonl  yl2_naidistulem.jsonl
# minu_andmed.json   yl1_tulem.jsonl	  yl2_tulem.jsonl
# Praktikum_6.ipynb  yl1_tulem___.jsonl
#
# '/content/drive/MyDrive/eesti keel pythonis/praks6/aja_json':
# aja_EPL_100.json  aja_EPL_44.json  aja_EPL_82.json  aja_pm_30.json
# aja_EPL_101.json  aja_EPL_45.json  aja_EPL_83.json  aja_pm_31.json
# aja_EPL_102.json  aja_EPL_46.json  aja_EPL_84.json  aja_pm_32.json
# aja_EPL_103.json  aja_EPL_47.json  aja_EPL_85.json  aja_pm_33.json
# aja_EPL_104.json  aja_EPL_48.json  aja_EPL_86.json  aja_pm_34.json
# aja_EPL_105.json  aja_EPL_49.json  aja_EPL_87.json  aja_pm_35.json
# aja_EPL_10.json   aja_EPL_4.json   aja_EPL_88.json  aja_pm_36.json
# aja_EPL_11.json   aja_EPL_50.json  aja_EPL_89.json  aja_pm_37.json
# aja_EPL_12.json   aja_EPL_51.json  aja_EPL_8.json   aja_pm_38.json
# aja_EPL_13.json   aja_EPL_52.json  aja_EPL_90.json  aja_pm_39.json
# aja_EPL_14.json   aja_EPL_53.json  aja_EPL_91.json  aja_pm_3.json
# aja_EPL_15.json   aja_EPL_54.json  aja_EPL_92.json  aja_pm_40.json
# aja_EPL_16.json   aja_EPL_55.json  aja_EPL_93.json  aja_pm_41.json
# aja_EPL_18.json   aja_EPL_56.json  aja_EPL_94.json  aja_pm_42.json
# aja_EPL_19.json   aja_EPL_57.json  aja_EPL_95.json  aja_pm_43.json
# aja_EPL_1.json	  aja_EPL_58.json  aja_EPL_96.json  aja_pm_44.json
# aja_EPL_20.json   aja_EPL_59.json  aja_EPL_97.json  aja_pm_45.json
# aja_EPL_21.json   aja_EPL_5.json   aja_EPL_98.json  aja_pm_46.json
# aja_EPL_22.json   aja_EPL_60.json  aja_EPL_99.json  aja_pm_47.json
# aja_EPL_23.json   aja_EPL_61.json  aja_EPL_9.json   aja_pm_48.json
# aja_EPL_24.json   aja_EPL_62.json  aja_pm_10.json   aja_pm_49.json
# aja_EPL_25.json   aja_EPL_63.json  aja_pm_11.json   aja_pm_4.json
# aja_EPL_26.json   aja_EPL_64.json  aja_pm_12.json   aja_pm_50.json
# aja_EPL_27.json   aja_EPL_65.json  aja_pm_13.json   aja_pm_51.json
# aja_EPL_28.json   aja_EPL_66.json  aja_pm_14.json   aja_pm_52.json
# aja_EPL_29.json   aja_EPL_67.json  aja_pm_15.json   aja_pm_53.json
# aja_EPL_2.json	  aja_EPL_68.json  aja_pm_16.json   aja_pm_54.json
# aja_EPL_30.json   aja_EPL_69.json  aja_pm_17.json   aja_pm_55.json
# aja_EPL_31.json   aja_EPL_6.json   aja_pm_18.json   aja_pm_56.json
# aja_EPL_32.json   aja_EPL_70.json  aja_pm_19.json   aja_pm_57.json
# aja_EPL_33.json   aja_EPL_71.json  aja_pm_1.json    aja_pm_58.json
# aja_EPL_34.json   aja_EPL_72.json  aja_pm_20.json   aja_pm_59.json
# aja_EPL_35.json   aja_EPL_73.json  aja_pm_21.json   aja_pm_5.json
# aja_EPL_36.json   aja_EPL_74.json  aja_pm_22.json   aja_pm_60.json
# aja_EPL_37.json   aja_EPL_75.json  aja_pm_23.json   aja_pm_61.json
# aja_EPL_38.json   aja_EPL_76.json  aja_pm_24.json   aja_pm_62.json
# aja_EPL_39.json   aja_EPL_77.json  aja_pm_25.json   aja_pm_63.json
# aja_EPL_3.json	  aja_EPL_78.json  aja_pm_26.json   aja_pm_6.json
# aja_EPL_40.json   aja_EPL_79.json  aja_pm_27.json   aja_pm_7.json
# aja_EPL_41.json   aja_EPL_7.json   aja_pm_28.json   aja_pm_8.json
# aja_EPL_42.json   aja_EPL_80.json  aja_pm_29.json   aja_pm_9.json
# aja_EPL_43.json   aja_EPL_81.json  aja_pm_2.json
#
# '/content/drive/MyDrive/eesti keel pythonis/praks7':
# anekdoodid.csv		  olendid_lisamaterjal.txt  Praktikum7.ipynb
# anekdoodi_minikorpus.csv  parasiitlusest.txt	    telegram.txt
#
# '/content/drive/MyDrive/eesti keel pythonis/praks8':
# edt_laused.conllu  kenneth_robinson.html  puu1.png
# hargla		   Praktikum8.ipynb	  syntaksiliides_ee.pdf
#
# '/content/drive/MyDrive/eesti keel pythonis/praks8/hargla':
# ilu_hargla_jutt10.txt  ilu_hargla_jutt19.txt  ilu_hargla_jutt3.txt
# ilu_hargla_jutt11.txt  ilu_hargla_jutt1.txt   ilu_hargla_jutt4.txt
# ilu_hargla_jutt12.txt  ilu_hargla_jutt20.txt  ilu_hargla_jutt5.txt
# ilu_hargla_jutt13.txt  ilu_hargla_jutt21.txt  ilu_hargla_jutt6.txt
# ilu_hargla_jutt14.txt  ilu_hargla_jutt22.txt  ilu_hargla_jutt7.txt
# ilu_hargla_jutt15.txt  ilu_hargla_jutt23.txt  ilu_hargla_jutt8.txt
# ilu_hargla_jutt16.txt  ilu_hargla_jutt24.txt  ilu_hargla_jutt9.txt
# ilu_hargla_jutt17.txt  ilu_hargla_jutt25.txt
# ilu_hargla_jutt18.txt  ilu_hargla_jutt2.txt
#
# '/content/drive/MyDrive/eesti keel pythonis/praks9':
# aja_pm_EPL
# foorumid_xml
# Harjutuse_lahendus.ipynb
# Lisamaterjal_margenduste_visualiseerimine_II.ipynb
# Lisamaterjal_Sissejuhatus_objekt-orienteeritud_programmeerimisse.ipynb
# aja_EPL_1999_03_23__22.json	   aja_pm_1999_03_29__62.json
# aja_EPL_1999_03_23__24.json	   aja_pm_1999_03_29__64.json
# aja_EPL_1999_03_23__26.json	   aja_pm_1999_03_29__66.json
# aja_EPL_1999_03_23__28.json	   aja_pm_1999_03_30.tasak__38.json
# aja_EPL_1999_03_23__31.json	   aja_pm_1999_03_30.tasak__58.json
# aja_EPL_1999_03_23__33.json	   aja_pm_1999_03_30.tasak__61.json
# aja_EPL_1999_03_23__35.json	   aja_pm_1999_03_31__44.json
# aja_EPL_1999_03_23__37.json	   aja_pm_1999_03_31__64.json
# aja_EPL_1999_03_23__7.json	   aja_pm_1999_03_31__66.json
# aja_EPL_1999_03_23__9.json
#
# '/content/drive/MyDrive/eesti keel pythonis/praks9/foorumid_xml':
# Turg_valiidne.xml
#
# '/content/drive/MyDrive/koodihalduse alused':
# praks1	praks2
#
# '/content/drive/MyDrive/koodihalduse alused/praks1':
# 'GNU GENERAL PUBLIC LICENSE.txt'   README.md
#
# '/content/drive/MyDrive/koodihalduse alused/praks2':
# Intro.ipynb	   Matplotlib.ipynb  output.parquet  README.md
# Islander_data.csv  output.csv	     Pandas.ipynb
#
# /content/drive/MyDrive/masinope:
# 'homework 01'  'homework 05'		    praks3dzvinka   praks7
# 'homework 02'  'praks 1 - group6 dzvinka'   praks4dzvinka   praks8
# 'homework 03'  'praks 1 - mariliis'	    praks5	    praks9
# 'homework 04'  'praks 2 . mariliis'	    praks6	    project
#
# '/content/drive/MyDrive/masinope/homework 01':
# 'Supervised_learning_HW.ipynb koopia'
#
# '/content/drive/MyDrive/masinope/homework 02':
# 2_Unsupervised_learning_HW.ipynb
#
# '/content/drive/MyDrive/masinope/homework 03':
# 3_Deeplearning_HW.ipynb  elephants.csv	rhino.csv
#
# '/content/drive/MyDrive/masinope/homework 04':
# 4_Regularisation_HW.ipynb
#
# '/content/drive/MyDrive/masinope/homework 05':
# 5_Ensemblelearning_HW.ipynb
#
# '/content/drive/MyDrive/masinope/praks 1 - group6 dzvinka':
# 1_Supervised_learning_partI.ipynb
#
# '/content/drive/MyDrive/masinope/praks 1 - mariliis':
# 1_Supervised_learning_partI.ipynb
#
# '/content/drive/MyDrive/masinope/praks 2 . mariliis':
# 1_Supervised_learning_partII.ipynb
#
# /content/drive/MyDrive/masinope/praks3dzvinka:
# 1_Supervised_learning_partII.ipynb  2_Unsupervised_learning_partI.ipynb
# 1_Supervised_learning_partI.ipynb   nyc_data_2.zip
#
# /content/drive/MyDrive/masinope/praks4dzvinka:
# 1_Supervised_learning_partII.ipynb    2_Unsupervised_learning_partI.ipynb
# 1_Supervised_learning_partI.ipynb     nyc_data_2.zip
# 2_Unsupervised_learning_partII.ipynb
#
# /content/drive/MyDrive/masinope/praks5:
# 1_Supervised_learning_partII.ipynb    2_Unsupervised_learning_partI.ipynb
# 1_Supervised_learning_partI.ipynb     3_Deeplearning_partI.ipynb
# 2_Unsupervised_learning_partII.ipynb
#
# /content/drive/MyDrive/masinope/praks6:
#  3_Deeplearning_partII.ipynb  'Allalaaditud fail.csv'   data
#
# /content/drive/MyDrive/masinope/praks6/data:
# leopard
#
# /content/drive/MyDrive/masinope/praks6/data/leopard:
#
# /content/drive/MyDrive/masinope/praks7:
# 4_Regularisation.ipynb
#
# /content/drive/MyDrive/masinope/praks8:
# 5_Ensemblelearning_partI.ipynb
#
# /content/drive/MyDrive/masinope/praks9:
# 5_Ensemblelearning_partII.ipynb
#
# /content/drive/MyDrive/masinope/project:
# DiaData_sisse_v2.ipynb	hendrik_experiments  merette_experiments  README.md
#
# /content/drive/MyDrive/masinope/project/hendrik_experiments:
# 'Baasi reeglid CGM est.docx'
# 'CONFIDENTIALITY AGREEMENT mashine learning.docx'
#  DCLP3_sisse_v2_hendrik.ipynb
# 'Diabetic patient graphical data.pptx'
#  insuliinigraafik.png
#  insuliinigraafik_.png
# 'INTELLECTUAL PROPERTY ASSIGNMENT AGREEMENT Mashine learning.asice'
# 'INTELLECTUAL PROPERTY ASSIGNMENT AGREEMENT Mashine learning.docx'
#  machine_learning_project.ipynb
#  merged_preprocessed.csv
#  minimed3.png
#  NDA_and_IP_agreements.asice
#  NDA_and_IP_agreements_final.asice
#  patient_summary.csv
#  proba1_1.csv
#  proba1_2.csv
#  Proba1.csv
#  Proba1_graafikutega2.xlsx
#  Proba1_graafikutega.xlsx
#  Proba1.xlsx
#  recommendation_rules_summary.csv
#  weekly_insights_summary.txt
#
# /content/drive/MyDrive/masinope/project/merette_experiments:
# cgm.txt  D1NAMO.ipynb  DCLP3.ipynb  maindatabase1.zip
#
# '/content/drive/MyDrive/notebook converter':
#  Intro_to_R.ipynb  'Notebook_converter!.ipynb'	 Praktikum7-2025S.Rmd
#
# /content/drive/MyDrive/transformers:
# hw02  hw03  lab1  lab2	projekt
#
# /content/drive/MyDrive/transformers/hw02:
# transformers2025_hw2.ipynb
#
# /content/drive/MyDrive/transformers/hw03:
# gpt_dev_flashattn_alert.ipynb  gpt_dev_modified.ipynb	    Hw3_description.pdf
# gpt_dev_flashattn.ipynb        gpt_dev_timer.ipynb	    input.txt
# gpt_dev.ipynb		       gpt_flashattention_patch.py  __pycache__
#
# /content/drive/MyDrive/transformers/hw03/__pycache__:
# gpt_flashattention_patch.cpython-312.pyc
#
# /content/drive/MyDrive/transformers/lab1:
# data  transformers2023_lab1_toy_model.ipynb
#
# /content/drive/MyDrive/transformers/lab1/data:
# dev.src  dev.tgt  train.src  train.tgt
#
# /content/drive/MyDrive/transformers/lab2:
# transformers2025_lab2_encoder_from_scratch.ipynb
#
# /content/drive/MyDrive/transformers/projekt:
# 'Qwen3_(4B)_Instruct.ipynb'   tf_project
#
# /content/drive/MyDrive/transformers/projekt/tf_project:
# datasets		   hpc			    requirements.txt
# eneko_trying_out_things    oskar_trying_out_things  src
# hendrik_trying_out_things  README.md
#
# /content/drive/MyDrive/transformers/projekt/tf_project/datasets:
# sample.py
#
# /content/drive/MyDrive/transformers/projekt/tf_project/eneko_trying_out_things:
# sample.py
#
# /content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things:
#  generate_image.sh     llama_local_notebook.sbatch  'Qwen3_(4B)_Instruct.ipynb'
#  gsm8k_datasets        maqa_datasets		     sample.py
#  hendrika_vllm.ipynb   one_promp_confidence.ipynb    strategyqa_dataset
#  jupyter.slurm	       one_prompt_confidence.py
#
# /content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things/gsm8k_datasets:
# 'test-00000-of-00001 (1).parquet'  'train-00000-of-00001 (1).parquet'
#  test-00000-of-00001.parquet	    train-00000-of-00001.parquet
#
# /content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things/maqa_datasets:
#  MAQA_commonsense_reasoning.json
#  MAQA_mathmatical_reasoning.json
#  MAQA_world_knowledge_HLS.json
#  MAQA_world_knowledge_nq.json
# 'single_commonsens_reasoning(StrategyQA).json'
# 'single_mathematical_reasoning(gsm8k).json'
# 'single_world_knowledge(NQ).json'
#
# /content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things/strategyqa_dataset:
# bart_decomp_dev_predictions.jsonl
# dev.json
# queries_cache.json
# strategyqa_train_paragraphs.json
# train.json
# transformer_qa_ORA-P_dev_no_placeholders.json
# transformer_qa_ORA-P_train_no_placeholders.json
#
# /content/drive/MyDrive/transformers/projekt/tf_project/hpc:
# how_to_hpc.txt	qwen2_local_notebook.sbatch
#
# /content/drive/MyDrive/transformers/projekt/tf_project/oskar_trying_out_things:
# one_promp_confidence.ipynb  one_prompt_confidence.py
#
# /content/drive/MyDrive/transformers/projekt/tf_project/src:
# confidence_methods.py  model.py  __pycache__  run_model_on_dataset.py
#
# /content/drive/MyDrive/transformers/projekt/tf_project/src/__pycache__:
# model.cpython-310.pyc
#
# /content/sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md
#
# Contents of strategyqa_dataset:
# ls: cannot access '/content/strategyqa_dataset': No such file or directory
#
# Contents of maqa_datasets:
# ls: cannot access '/content/maqa_datasets': No such file or directory
#
# Contents of gsm8k_datasets:
# ls: cannot access '/content/gsm8k_datasets': No such file or directory

# %% [markdown]
# **Reasoning**:
# The previous attempt to list the dataset directories failed because they were not located directly under `/content/`. Based on the `ls -R /content/` output, the datasets are located within `/content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things/`. I will now list the contents of these directories using their correct paths to identify the 'test' and 'train' splits and their file extensions.

# %%
import os

# Base path for the datasets
base_path = "/content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things"

# 1. List the contents of 'strategyqa_dataset' directory
print("\nContents of strategyqa_dataset:")
# !ls -R {base_path}/strategyqa_dataset

# 2. List the contents of 'maqa_datasets' directory
print("\nContents of maqa_datasets:")
# !ls -R {base_path}/maqa_datasets

# 3. List the contents of 'gsm8k_datasets' directory
print("\nContents of gsm8k_datasets:")
# !ls -R {base_path}/gsm8k_datasets
# Out:
# Contents of strategyqa_dataset:
# /content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things/strategyqa_dataset:
# bart_decomp_dev_predictions.jsonl
# dev.json
# queries_cache.json
# strategyqa_train_paragraphs.json
# train.json
# transformer_qa_ORA-P_dev_no_placeholders.json
# transformer_qa_ORA-P_train_no_placeholders.json
#
# Contents of maqa_datasets:
# /content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things/maqa_datasets:
#  MAQA_commonsense_reasoning.json
#  MAQA_mathmatical_reasoning.json
#  MAQA_world_knowledge_HLS.json
#  MAQA_world_knowledge_nq.json
# 'single_commonsens_reasoning(StrategyQA).json'
# 'single_mathematical_reasoning(gsm8k).json'
# 'single_world_knowledge(NQ).json'
#
# Contents of gsm8k_datasets:
# /content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things/gsm8k_datasets:
# 'test-00000-of-00001 (1).parquet'  'train-00000-of-00001 (1).parquet'
#  test-00000-of-00001.parquet	    train-00000-of-00001.parquet

# %% [markdown]
# ### Summary of Dataset Splits and File Types:
#
# **1. `strategyqa_dataset`:**
# *   **Test Split:** `dev.json` (JSON format)
# *   **Train Split:** `train.json` (JSON format)
#
# **2. `maqa_datasets`:**
# *   This directory contains several JSON files, but no files explicitly named 'test' or 'train'. It appears the data is organized by reasoning type (e.g., `MAQA_commonsense_reasoning.json`, `MAQA_mathmatical_reasoning.json`, `MAQA_world_knowledge_HLS.json`, `MAQA_world_knowledge_nq.json`, and other `single_...json` files). Further inspection within these files might be needed to identify the 'test' and 'train' splits if they are combined or differently named.
#
# **3. `gsm8k_datasets`:**
# *   **Test Split:** `test-00000-of-00001.parquet` (Parquet format)
# *   **Train Split:** `train-00000-of-00001.parquet` (Parquet format)

# %% [markdown]
# ## Load Data into DataFrames
#
# ### Subtask:
# Load the 'test' and 'train' splits from 'strategyqa_dataset' and 'gsm8k_datasets', and all JSON files from 'maqa_datasets' into pandas DataFrames.

# %% [markdown]
# **Reasoning**:
# The subtask requires loading specific 'test' and 'train' splits from `strategyqa_dataset` and `gsm8k_datasets` and all JSON files from `maqa_datasets` into pandas DataFrames. This involves importing pandas, setting the base path, reading JSON and Parquet files, and iterating through a directory for multiple JSON files.

# %%
import pandas as pd
import os

# Define the base path for the datasets
base_path = '/content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things'

# 3. For strategyqa_dataset:
strategyqa_dev_df = pd.read_json(os.path.join(base_path, 'strategyqa_dataset', 'dev.json'))
strategyqa_train_df = pd.read_json(os.path.join(base_path, 'strategyqa_dataset', 'train.json'))

# 4. For gsm8k_datasets:
gsm8k_test_df = pd.read_parquet(os.path.join(base_path, 'gsm8k_datasets', 'test-00000-of-00001.parquet'))
gsm8k_train_df = pd.read_parquet(os.path.join(base_path, 'gsm8k_datasets', 'train-00000-of-00001.parquet'))

# 5. For maqa_datasets:
maqa_dfs = {}
maqa_dataset_path = os.path.join(base_path, 'maqa_datasets')
for filename in os.listdir(maqa_dataset_path):
    if filename.endswith('.json'):
        file_path = os.path.join(maqa_dataset_path, filename)
        df_name = os.path.splitext(filename)[0] # Get filename without extension
        maqa_dfs[df_name] = pd.read_json(file_path)

# 6. Print the first few rows and shape of each loaded DataFrame
print("\n--- strategyqa_dev_df ---")
print(strategyqa_dev_df.head())
print(f"Shape: {strategyqa_dev_df.shape}")

print("\n--- strategyqa_train_df ---")
print(strategyqa_train_df.head())
print(f"Shape: {strategyqa_train_df.shape}")

print("\n--- gsm8k_test_df ---")
print(gsm8k_test_df.head())
print(f"Shape: {gsm8k_test_df.shape}")

print("\n--- gsm8k_train_df ---")
print(gsm8k_train_df.head())
print(f"Shape: {gsm8k_train_df.shape}")

print("\n--- maqa_datasets DataFrames ---")
for name, df in maqa_dfs.items():
    print(f"\nDataFrame: {name}")
    print(df.head())
    print(f"Shape: {df.shape}")
# Out:
# --- strategyqa_dev_df ---
#                     qid                              term  \
# 0  e0044a7b4d146d611e73                   Albany, Georgia
# 1  c69397b4341b65ed080f  Saint Vincent and the Grenadines
# 2  be5c9933987f046b476e                             Greed
# 3  1932e05f10680ece229f                      Sea of Japan
# 4  fb8b656051c742f5bd27                           Lil Jon
#
#                                          description  \
# 0                     City in Georgia, United States
# 1                           Country in the Caribbean
# 2  an inordinate or insatiable longing, especiall...
# 3       Marginal sea between Japan, Russia and Korea
# 4  American rapper, record producer and DJ from G...
#
#                                             question  answer  \
# 0  Will the Albany in Georgia reach a hundred tho...   False
# 1  Is the language used in Saint Vincent and the ...    True
# 2  Is greed the most prevalent of the Seven Deadl...   False
# 3  Would the top of Mount Fuji stick out of the S...    True
# 4  Was Lil Jon's top ranked Billboard song a coll...   False
#
#                                                facts  \
# 0  [Albany, GA has around 75,000 people, Albany, ...
# 1  [The primary language spoken in Saint Vincent ...
# 2  [Greed is a longing for wealth and power., Whi...
# 3  [The average depth of the Sea of Japan is  5,7...
# 4  [Lil Jon's highest ranked billboard song was Y...
#
#                                        decomposition  \
# 0  [What is the population of Albany, Georgia?, W...
# 1  [What language is used in Saint Vincent and th...
# 2  [Is greed a  deadly sin?, Is gluttonly a deadl...
# 3  [How tall is Mount Fuji?, What is the maximum ...
# 4  [What is Lil Jon's top ranked Billboard song?,...
#
#                                             evidence
# 0  [[[['Albany, Georgia-1']], [['Albany, New York...
# 1  [[[['Demographics of Saint Vincent and the Gre...
# 2  [[[['Seven deadly sins-1']], [['Seven deadly s...
# 3  [[[['Mount Fuji-18']], [['Sea of Japan-15']], ...
# 4  [[[['Yeah! (Usher song)-1']], [['Yeah! (Usher ...
# Shape: (229, 8)
#
# --- strategyqa_train_df ---
#                     qid               term  \
# 0  2bc9c4f9c19c167187f2       Genghis Khan
# 1  03caf265939fab701dee         The Police
# 2  aadc8000bfcb987d6b9d  Depression (mood)
# 3  d1a138ecfa13ee277ab4          Grey seal
# 4  f945d8a4274bb3805989     Pound sterling
#
#                                          description  \
# 0  founder and first Great Khan of the Mongol Empire
# 1                                  English rock band
# 2                      state of low mood and fatigue
# 3                                    species of seal
# 4  Official currency of the United Kingdom and ot...
#
#                                             question  answer  \
# 0  Are more people today related to Genghis Khan ...    True
# 1  Could the members of The Police perform lawful...   False
# 2  Would a Monoamine Oxidase candy bar cheer up a...   False
# 3      Would a dog respond to bell before Grey seal?    True
# 4                      Is a pound sterling valuable?   False
#
#                                                facts  \
# 0  [Julius Caesar had three children., Genghis Kh...
# 1  [The members of The Police were musicians, not...
# 2  [Depression is caused by low levels of seroton...
# 3  [Grey seals have no ear flaps and their ears c...
# 4  [A pound sterling is fiat money., Fiat money i...
#
#                                        decomposition  \
# 0  [How many kids did Julius Caesar have?, How ma...
# 1  [Who can perform lawful arrests?, Are members ...
# 2  [Depression is caused by low levels of what ch...
# 3  [How sensitive is a grey seal's hearing on lan...
# 4  [What is the value of the Pound Sterling based...
#
#                                             evidence
# 0  [[[['Caesarion-2', 'Julia (daughter of Caesar)...
# 1  [[[['Arrest-2']], [["Citizen's arrest-2", 'The...
# 2  [[[['Monoamine oxidase-8']], [['Monoamine oxid...
# 3  [[[['Pinniped-24']], [['Hearing range-11', 'He...
# 4  [[[['Pound sterling-16']], [['Pound sterling-1...
# Shape: (2061, 8)
#
# --- gsm8k_test_df ---
#                                             question  \
# 0  Janet’s ducks lay 16 eggs per day. She eats th...
# 1  A robe takes 2 bolts of blue fiber and half th...
# 2  Josh decides to try flipping a house.  He buys...
# 3  James decides to run 3 sprints 3 times a week....
# 4  Every day, Wendi feeds each of her chickens th...
#
#                                               answer
# 0  Janet sells 16 - 3 - 4 = <<16-3-4=9>>9 duck eg...
# 1  It takes 2/2=<<2/2=1>>1 bolt of white fiber\nS...
# 2  The cost of the house and repairs came out to ...
# 3  He sprints 3*3=<<3*3=9>>9 times\nSo he runs 9*...
# 4  If each chicken eats 3 cups of feed per day, t...
# Shape: (1319, 2)
#
# --- gsm8k_train_df ---
#                                             question  \
# 0  Natalia sold clips to 48 of her friends in Apr...
# 1  Weng earns $12 an hour for babysitting. Yester...
# 2  Betty is saving money for a new wallet which c...
# 3  Julie is reading a 120-page book. Yesterday, s...
# 4  James writes a 3-page letter to 2 different fr...
#
#                                               answer
# 0  Natalia sold 48/2 = <<48/2=24>>24 clips in May...
# 1  Weng earns 12/60 = $<<12/60=0.2>>0.2 per minut...
# 2  In the beginning, Betty has only 100 / 2 = $<<...
# 3  Maila read 12 x 2 = <<12*2=24>>24 pages today....
# 4  He writes each friend 3*2=<<3*2=6>>6 pages a w...
# Shape: (7473, 2)
#
# --- maqa_datasets DataFrames ---
#
# DataFrame: single_mathematical_reasoning(gsm8k)
#                                             question   answer
# 0  Janet’s ducks lay 16 eggs per day. She eats th...     18.0
# 1  A robe takes 2 bolts of blue fiber and half th...      3.0
# 2  Josh decides to try flipping a house.  He buys...  70000.0
# 3  James decides to run 3 sprints 3 times a week....    540.0
# 4  Every day, Wendi feeds each of her chickens th...     20.0
# Shape: (1319, 2)
#
# DataFrame: MAQA_commonsense_reasoning
#                                             question              answer
# 0  (a) Can preventive healthcare reduce STI trans...           [a, b, e]
# 1  (a) Are those incapable of reproduction incapa...     [c, d, e, h, j]
# 2  (a) Did Kim Il-sung network on LinkedIn?\n(b) ...     [c, f, g, h, k]
# 3  (a) Is Mozambique Drill an easy shot for Unite...  [a, b, c, f, g, j]
# 4  (a) Was Aristotle a member of the House of Lor...              [c, f]
# Shape: (1000, 2)
#
# DataFrame: MAQA_mathmatical_reasoning
#                                             question        answer
# 0      List all generators of the finite field Z_11.  [2, 6, 7, 8]
# 1  Consider G as a group and H as its subgroup. F...  [1, 2, 4, 5]
# 2  List all integer solutions x for the quadratic...       [-9, 7]
# 3  List all distinct prime factors of the least c...     [2, 3, 5]
# 4  List all the integer values of c that make the...   [9, 12, 15]
# Shape: (400, 2)
#
# DataFrame: MAQA_world_knowledge_nq
#                                             question  \
# 0  Who were the original members of the Traveling...
# 1  Who were the original members of the band The ...
# 2  Who were the writers of the song 'Tell Your He...
# 3  Who were the lyricists credited for the song '...
# 4  Who were the writers of the song 'Take Me to t...
#
#                                               answer
# 0  [Bob Dylan, Tom Petty, George Harrison, Jeff L...
# 1  [Micky Dolenz, Peter Tork, [Michael Nesmith, M...
# 2       [Bernie Herms, Matthew West, Randy Phillips]
# 3  [[Michael Busbee, busbee, Michael James Ryan B...
# 4                  [Al Green, Mabon "Teenie" Hodges]
# Shape: (592, 2)
#
# DataFrame: single_commonsens_reasoning(StrategyQA)
#                                             question answer
# 0  Are more people today related to Genghis Khan ...   true
# 1  Could the members of The Police perform lawful...  false
# 2  Would a Monoamine Oxidase candy bar cheer up a...  false
# 3      Would a dog respond to bell before Grey seal?   true
# 4                      Is a pound sterling valuable?  false
# Shape: (2290, 2)
#
# DataFrame: MAQA_world_knowledge_HLS
#                                             question  \
# 0   What are the official languages spoken in India?
# 1  What are the full names of elements in the per...
# 2  Which countries are members of the European Un...
# 3    Which countries are considered part of the G20?
# 4    What are the major phyla in the animal kingdom?
#
#                                               answer
# 0  [Assamese, Bengali, Bodo, Dogri, English, Guja...
# 1  [Scandium, Titanium, Vanadium, Chromium, Manga...
# 2  [Austria, Belgium, Bulgaria, Croatia, Cyprus, ...
# 3  [Argentina, Australia, Brazil, Canada, China, ...
# 4  [Porifera, Cnidaria, Platyhelminthes, Nematoda...
# Shape: (50, 2)
#
# DataFrame: single_world_knowledge(NQ)
#                                       question  \
# 0      when did the eagles win last super bowl
# 1  who won last year's ncaa women's basketball
# 2         who was the ruler of england in 1616
# 3    what is the hot coffee mod in san andreas
# 4              who sang i ran all the way home
#
#                                 answer
# 0                               [2017]
# 1                     [South Carolina]
# 2                            [James I]
# 3  [a normally inaccessible mini-game]
# 4                        [The Impalas]
# Shape: (1288, 2)

# %% [markdown]
# ## Store and Access DataFrames
#
# ### Subtask:
# Organize the loaded DataFrames into a single dictionary for easy access and further processing.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The initial attempt to locate datasets under `/content/` failed, but the correct base path was identified as `/content/drive/MyDrive/transformers/projekt/tf_project/hendrik_trying_out_things/`.
# *   **`strategyqa_dataset`**:
#     *   `dev.json` (acting as test split) was loaded into `strategyqa_dev_df` with 229 rows and 8 columns (`qid`, `term`, `description`, `question`, `answer`, `facts`, `decomposition`, `evidence`).
#     *   `train.json` was loaded into `strategyqa_train_df` with 2061 rows and 8 columns.
# *   **`gsm8k_datasets`**:
#     *   `test-00000-of-00001.parquet` was loaded into `gsm8k_test_df` with 1319 rows and 2 columns (`question`, `answer`).
#     *   `train-00000-of-00001.parquet` was loaded into `gsm8k_train_df` with 7473 rows and 2 columns.
# *   **`maqa_datasets`**: This directory did not contain explicit 'test' or 'train' splits. Instead, seven individual JSON files were loaded, categorized by reasoning type, each with 2 columns:
#     *   `single_mathematical_reasoning(gsm8k)`: 1319 rows.
#     *   `MAQA_commonsense_reasoning`: 1000 rows.
#     *   `MAQA_mathmatical_reasoning`: 400 rows.
#     *   `MAQA_world_knowledge_nq`: 592 rows.
#     *   `single_commonsens_reasoning(StrategyQA)`: 2290 rows.
#     *   `MAQA_world_knowledge_HLS`: 50 rows.
#     *   `single_world_knowledge(NQ)`: 1288 rows.
#
# ### Insights or Next Steps
#
# *   Organize all loaded DataFrames into a single dictionary for centralized and efficient access for subsequent analysis steps.
# *   Given the varying column structures (e.g., `strategyqa` having 8 columns, `gsm8k` and `maqa` datasets having 2 columns), consider a standardization process or specific handling for each dataset type during combined processing.

# %%
print("\n--- Columns for strategyqa_dev_df ---")
print(strategyqa_dev_df.columns)

print("\n--- Columns for strategyqa_train_df ---")
print(strategyqa_train_df.columns)

print("\n--- Columns for gsm8k_test_df ---")
print(gsm8k_test_df.columns)

print("\n--- Columns for gsm8k_train_df ---")
print(gsm8k_train_df.columns)

print("\n--- Columns for maqa_datasets DataFrames ---")
for name, df in maqa_dfs.items():
    print(f"\nDataFrame: {name}")
    print(df.columns)
# Out:
# --- Columns for strategyqa_dev_df ---
# Index(['qid', 'term', 'description', 'question', 'answer', 'facts',
#        'decomposition', 'evidence'],
#       dtype='object')
#
# --- Columns for strategyqa_train_df ---
# Index(['qid', 'term', 'description', 'question', 'answer', 'facts',
#        'decomposition', 'evidence'],
#       dtype='object')
#
# --- Columns for gsm8k_test_df ---
# Index(['question', 'answer'], dtype='object')
#
# --- Columns for gsm8k_train_df ---
# Index(['question', 'answer'], dtype='object')
#
# --- Columns for maqa_datasets DataFrames ---
#
# DataFrame: single_mathematical_reasoning(gsm8k)
# Index(['question', 'answer'], dtype='object')
#
# DataFrame: MAQA_commonsense_reasoning
# Index(['question', 'answer'], dtype='object')
#
# DataFrame: MAQA_mathmatical_reasoning
# Index(['question', 'answer'], dtype='object')
#
# DataFrame: MAQA_world_knowledge_nq
# Index(['question', 'answer'], dtype='object')
#
# DataFrame: single_commonsens_reasoning(StrategyQA)
# Index(['question', 'answer'], dtype='object')
#
# DataFrame: MAQA_world_knowledge_HLS
# Index(['question', 'answer'], dtype='object')
#
# DataFrame: single_world_knowledge(NQ)
# Index(['question', 'answer'], dtype='object')

# %%
all_datasets = {
    'strategyqa_dev': strategyqa_dev_df,
    'strategyqa_train': strategyqa_train_df,
    'gsm8k_test': gsm8k_test_df,
    'gsm8k_train': gsm8k_train_df
}

# Add MAQA datasets to the main dictionary
for name, df in maqa_dfs.items():
    all_datasets[f'maqa_{name}'] = df

print("All loaded DataFrames are now organized into the 'all_datasets' dictionary.")
print(f"Total DataFrames in dictionary: {len(all_datasets)}")
print("Keys in all_datasets:")
for key in all_datasets.keys():
    print(f"- {key}")
# Out:
# All loaded DataFrames are now organized into the 'all_datasets' dictionary.
# Total DataFrames in dictionary: 11
# Keys in all_datasets:
# - strategyqa_dev
# - strategyqa_train
# - gsm8k_test
# - gsm8k_train
# - maqa_single_mathematical_reasoning(gsm8k)
# - maqa_MAQA_commonsense_reasoning
# - maqa_MAQA_mathmatical_reasoning
# - maqa_MAQA_world_knowledge_nq
# - maqa_single_commonsens_reasoning(StrategyQA)
# - maqa_MAQA_world_knowledge_HLS
# - maqa_single_world_knowledge(NQ)
